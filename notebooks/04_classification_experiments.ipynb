# %% [markdown]
# # 04 - Experimentos de Clasificacion Multi-Task
#
# Training curves, confusion matrices, classification reports, comparacion de backbone congelado vs fine-tuned.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

import json
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import yaml
from sklearn.metrics import classification_report, confusion_matrix

from src.classification.model import MultiTaskFashionClassifier
from src.classification.dataset import DeepFashionDataset
from src.classification.train import evaluate

sns.set_theme(style='whitegrid')

# %%
with open('../config/pipeline_config.yaml') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# ## Curvas de train/val loss y accuracy
# Requieren logs de entrenamiento (exportados desde `train.py`).

# %%
# TODO: cargar training_log.json generado por train.py y plotear

# %% [markdown]
# ## Cargar mejor checkpoint

# %%
ckpt_path = Path('../models/best_multitask.pth')
model = MultiTaskFashionClassifier(config, pretrained=False)
if ckpt_path.exists():
    state = torch.load(ckpt_path, map_location='cpu')
    model.load_state_dict(state.get('model_state', state))
    print('Checkpoint cargado.')
else:
    print('No hay checkpoint aun.')

# %% [markdown]
# ## Confusion matrices por head

# %%
# TODO: correr evaluate() sobre val set y plotear confusion matrices

# %% [markdown]
# ## Attention maps / GradCAM
# Visualizar que regiones mira el modelo para cada head.

# %%
# TODO: attention rollout sobre ViT para 5-10 imagenes
